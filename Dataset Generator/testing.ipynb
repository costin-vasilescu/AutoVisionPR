# %%
from LP import LicensePlate, PlateType
from LPDataset import LicensePlateDataset
from matplotlib import pyplot as plt
# import image_filters as imgf
# import albumentations as A

# %matplotlib inline
plt.style.use('dark_background')

# %%
plate_img = LicensePlate(plate_type=PlateType.PROVISIONAL).generate_image()
plt.imshow(plate_img)

# %%
augmented_plate_img = LicensePlateDataset().random_plate(plate_type=None)
plt.imshow(augmented_plate_img)
